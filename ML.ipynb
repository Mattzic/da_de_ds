# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['axes.unicode_minus']=False
pd.set_option('max_columns',100)

# %%
from sklearn.utils import shuffle
df = pd.read_csv('AllData.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df = shuffle(df)
df.head(500)
# Out:
#           Job Title               Salary Estimate  \
# 3978   DataEngineer   $74K-$134K (Glassdoor est.)
# 8184  DataScientist     $82K-$129K(Employer est.)
# 1014    DataAnalyst   $46K-$102K (Glassdoor est.)
# 4248   DataEngineer  $100K-$181K (Glassdoor est.)
# 8077  DataScientist   $93K-$151K (Glassdoor est.)
# ...             ...                           ...
# 3234   DataEngineer   $70K-$138K (Glassdoor est.)
# 8573  DataScientist    $52K-$94K (Glassdoor est.)
# 4225   DataEngineer  $108K-$127K (Glassdoor est.)
# 2503   DataEngineer   $95K-$167K (Glassdoor est.)
# 4481   DataEngineer    $27K-$50K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 3978  Where good people build rewarding careers.\n\n...     3.4
# 8184  Position Summary\n\nSamsung Austin Semiconduct...     2.9
# 1014  KAYGEN is an emerging leader in providing top ...     3.9
# 4248  Mercari is the selling app. We make it super e...     2.7
# 8077  Job Description\nData Analyst\n\nAbout our cli...     4.9
# ...                                                 ...     ...
# 3234  MUST HAVE REQUIREMENT prior experience with De...     5.0
# 8573  Tiger Analytics is an advanced analytics consu...     4.6
# 4225  Posted: May 22, 2020\nRole Number:\n200172180\...     4.1
# 2503  Job Description\nData Engineer\n\nBigtime Ente...    -1.0
# 4481  Availity delivers revenue cycle and related bu...     4.2
#
#                       Company Name          Location      Headquarters  \
# 3978                      Allstate        Irving, TX    Northbrook, IL
# 8184  Samsung Austin Semiconductor        Austin, TX        Austin, TX
# 1014                   Kaygen Inc.       Phoenix, AZ        Irvine, CA
# 4248                       Mercari     Palo Alto, CA      Tokyo, Japan
# 8077                   Cypress HCM        Austin, TX  Walnut Creek, CA
# ...                            ...               ...               ...
# 3234              Global Force USA       Phoenix, AZ       Houston, TX
# 8573               Tiger Analytics      Columbus, OH   Santa Clara, CA
# 4225                         Apple   Santa Clara, CA     Cupertino, CA
# 2503               ingenium.agency   Los Angeles, CA           Unknown
# 4481                      Availity  Jacksonville, FL  Jacksonville, FL
#
#            Size  Founded               Type of ownership  \
# 3978     10000+     1931                Company - Public
# 8184  1001,5000     1996  Subsidiary or Business Segment
# 1014       1,50       -1               Company - Private
# 4248  1001,5000     2013               Company - Private
# 8077     51,200     2005               Company - Private
# ...         ...      ...                             ...
# 3234       1,50       -1               Company - Private
# 8573    201,500     2011               Company - Private
# 4225     10000+     1976                Company - Public
# 2503    Unknown       -1                              -1
# 4481   501,1000     2001               Company - Private
#
#                                    Industry                  Sector  \
# 3978        Insurance Agencies & Brokerages               Insurance
# 8184  Electrical & Electronic Manufacturing           Manufacturing
# 1014                             Consulting       Business Services
# 4248                               Internet  Information Technology
# 8077                 Staffing & Outsourcing       Business Services
# ...                                     ...                     ...
# 3234                             Accounting      Accounting & Legal
# 8573                             Consulting       Business Services
# 4225           Computer Hardware & Software  Information Technology
# 2503                                Unknown                 Unknown
# 4481       Health Care Services & Hospitals             Health Care
#
#                   Revenue                                        Competitors  \
# 3978          10000000000  Progressive Insurance, State Farm, Farmers Ins...
# 8184              Unknown           GLOBALFOUNDRIES, Intel Corporation, TSMC
# 1014      1000000,5000000                                                 -1
# 4248              Unknown                                                 -1
# 8077              Unknown                                                 -1
# ...                   ...                                                ...
# 3234     Less than1000000                                                 -1
# 8573    10000000,25000000            Mu Sigma, LatentView Analytics, Fractal
# 4225          10000000000             Google, Microsoft, Samsung Electronics
# 2503              Unknown                                                 -1
# 4481  100000000,500000000         Passport Health Communications, Claimlogic
#
#      Easy Apply  Lo Salary  Hi Salary  Expected Salary          Area State  \
# 3978         -1      74000     134000         104000.0        Irving    TX
# 8184         -1      82000     129000         105500.0        Austin    TX
# 1014         -1      46000     102000          74000.0       Phoenix    AZ
# 4248       True     100000     181000         140500.0     Palo Alto    CA
# 8077         -1      93000     151000         122000.0        Austin    TX
# ...         ...        ...        ...              ...           ...   ...
# 3234         -1      70000     138000         104000.0       Phoenix    AZ
# 8573         -1      52000      94000          73000.0      Columbus    OH
# 4225         -1     108000     127000         117500.0   Santa Clara    CA
# 2503         -1      95000     167000         131000.0   Los Angeles    CA
# 4481         -1      27000      50000          38500.0  Jacksonville    FL
#
#       Lo Em  Hi Em       Lo Rev       Hi Rev    BS_R    BS_E
# 3978  10000     -1  10000000000  10000000000   Large   Other
# 8184   1001   5000           -1           -1   Large   Large
# 1014      1     50      1000000      5000000   Small   Small
# 4248   1001   5000           -1           -1   Large   Large
# 8077     51    200           -1           -1  Medium  Medium
# ...     ...    ...          ...          ...     ...     ...
# 3234      1     50           -1      1000000   Micro   Small
# 8573    201    500     10000000     25000000  Medium   Large
# 4225  10000     -1  10000000000  10000000000   Large   Other
# 2503     -1     -1           -1           -1   Other   Other
# 4481    501   1000    100000000    500000000   Large   Large
#
# [500 rows x 26 columns]

# %%
x_df = df[['Job Title', 'State', 'Area', 'Company Name']]
y_df = df['Expected Salary']

# %%
x_df
# Out:
#           Job Title State          Area                  Company Name
# 3978   DataEngineer    TX        Irving                      Allstate
# 8184  DataScientist    TX        Austin  Samsung Austin Semiconductor
# 1014    DataAnalyst    AZ       Phoenix                   Kaygen Inc.
# 4248   DataEngineer    CA     Palo Alto                       Mercari
# 8077  DataScientist    TX        Austin                   Cypress HCM
# ...             ...   ...           ...                           ...
# 578     DataAnalyst    CA    Long Beach                       LEAPROS
# 6545  DataScientist    PA  Philadelphia                   Adaptimmune
# 4555   DataEngineer    FL  Jacksonville                        Humana
# 6962  DataScientist    CA     San Diego           Abbott Laboratories
# 5555  DataScientist    IL  Melrose Park             1-800-Flowers.com
#
# [8690 rows x 4 columns]

# %%
y_df
# Out:
# 3978    104000.0
# 8184    105500.0
# 1014     74000.0
# 4248    140500.0
# 8077    122000.0
#           ...
# 578      80000.0
# 6545     82500.0
# 4555     60500.0
# 6962     92000.0
# 5555     98000.0
# Name: Expected Salary, Length: 8690, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
x_df = x_df.apply(LabelEncoder().fit_transform)
x_df
# Out:
#       Job Title  State  Area  Company Name
# 3978          1     15   140           176
# 8184          2     15    15          2628
# 1014          0      0   226          1667
# 4248          1      1   218          1928
# 8077          2     15    15           837
# ...         ...    ...   ...           ...
# 578           0      1   166          1731
# 6545          2     13   225           103
# 4555          1      4   145          1438
# 6962          2      1   254            69
# 5555          2      6   182             2
#
# [8690 rows x 4 columns]

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.4, random_state=17)

# %%
from sklearn import metrics

def print_evaluation(t, p):
    mae = metrics.mean_absolute_error(t, p)
    mse = metrics.mean_squared_error(t, p)
    rmse = np.sqrt(mse)
    r2 = metrics.r2_score(t, p)
    print('MAE: ', mae)
    print('MSE: ', mse)
    print('RMSE: ', rmse)
    print('R2: ', r2)

def evaluate(t, p):
    mae = metrics.mean_absolute_error(t, p)
    mse = metrics.mean_squared_error(t, p)
    rmse = np.sqrt(mse)
    r2 = metrics.r2_score(t, p)
    return mae,mse,rmse,r2

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression(normalize=True)
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
print(lin_reg.intercept_)
# Out:
# 81304.06805630175

# %%
coeff_df = pd.DataFrame(lin_reg.coef_, x_df.columns, columns=['Coefficient'])
coeff_df
# Out:
#                Coefficient
# Job Title     17766.387082
# State         -1444.695370
# Area             32.723814
# Company Name      0.322136

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

pipeline = Pipeline([('std_scalar', StandardScaler())])
x_train = pipeline.fit_transform(x_train)
x_test = pipeline.transform(x_test)

pred = lin_reg.predict(x_test)
plt.scatter(y_test, pred)

# %%
sns.displot((y_test - pred), bins=50)

# %%
test_pred = lin_reg.predict(x_test)
train_pred = lin_reg.predict(x_train)

print('test set evaluation:\n')
print_evaluation(y_test, test_pred)
print('========================================')
print('train set evaluation:\n')
print_evaluation(y_train, train_pred)
# Out:
# test set evaluation:
#
# MAE:  28753.210668441374
# MSE:  1392383480.819868
# RMSE:  37314.65504087996
# R2:  -0.039367303919775276
# ========================================
# train set evaluation:
#
# MAE:  28485.033725630517
# MSE:  1354496780.0552542
# RMSE:  36803.48869407973
# R2:  -0.002982637684880496

# %%
from sklearn.model_selection import cross_val_score

def cross_val(model):
    pred = cross_val_score(model, x_df, y_df, cv=5, scoring='r2')
    return pred


evaluate_df = pd.DataFrame(data=[['Linear Regression', *evaluate(y_test, test_pred), cross_val(LinearRegression())]],
                          columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2', 'Cross Validation'])

evaluate_df
# Out:
#                Model           MAE           MSE          RMSE        R2  \
# 0  Linear Regression  28753.210668  1.392383e+09  37314.655041 -0.039367
#
#                                     Cross Validation
# 0  [0.24236148500517785, 0.1882864971041004, 0.24...

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree=6)

x_train_pr = poly_reg.fit_transform(x_train)
x_test_pr = poly_reg.transform(x_test)

lin_reg = LinearRegression(normalize=True)
lin_reg.fit(x_train_pr, y_train)

test_pred = lin_reg.predict(x_test_pr)
train_pred = lin_reg.predict(x_train_pr)

print('test set evaluation:\n')
print_evaluation(y_test, test_pred)
print('========================================')
print('train set evaluation:\n')
print_evaluation(y_train, train_pred)
# Out:
# test set evaluation:
#
# MAE:  22323.531501726124
# MSE:  843963611.4725258
# RMSE:  29051.051813532085
# R2:  0.37000963057527303
# ========================================
# train set evaluation:
#
# MAE:  21898.121451860377
# MSE:  810551815.1884949
# RMSE:  28470.191695675232
# R2:  0.39979968239949537

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(n_estimators=700, min_samples_leaf=20)
rf_reg.fit(x_train, y_train)

test_pred = rf_reg.predict(x_test)
train_pred = rf_reg.predict(x_train)

print('test set evaluation:\n')
print_evaluation(y_test, test_pred)
print('========================================')
print('train set evaluation:\n')
print_evaluation(y_train, train_pred)
# Out:
# test set evaluation:
#
# MAE:  21242.09395325713
# MSE:  770761809.3824905
# RMSE:  27762.597309734738
# R2:  0.4246523067693264
# ========================================
# train set evaluation:
#
# MAE:  20168.35540955199
# MSE:  692872943.389708
# RMSE:  26322.479810794957
# R2:  0.48693895579940216

# %%
sns.displot((y_test - test_pred), bins=50)

# %%
evaluate_df = pd.DataFrame(data=[['RF', *evaluate(y_test, test_pred), cross_val(RandomForestRegressor())]],
                          columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2', 'Cross Validation'])

evaluate_df
# Out:
#   Model           MAE           MSE         RMSE        R2  \
# 0    RF  21242.093953  7.707618e+08  27762.59731  0.424652
#
#                                     Cross Validation
# 0  [0.32839565260521786, 0.2649266682146547, 0.28...

# %% [markdown]
# ## Gradient boost

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.3, random_state=17)

# %%
from sklearn.ensemble import GradientBoostingRegressor

params = {'n_estimators': 1500,
          'max_depth': 5,
          'min_samples_split': 7,
          'learning_rate': 0.01,
          'loss': 'huber'}

gb_reg = GradientBoostingRegressor(**params)
gb_reg.fit(x_train, y_train)

test_pred = gb_reg.predict(x_test)
train_pred = gb_reg.predict(x_train)

print('test set evaluation:\n')
print_evaluation(y_test, test_pred)
print('========================================')
print('train set evaluation:\n')
print_evaluation(y_train, train_pred)
# Out:
# test set evaluation:
#
# MAE:  20918.18986160454
# MSE:  786266947.7557298
# RMSE:  28040.45198914828
# R2:  0.4116786149508157
# ========================================
# train set evaluation:
#
# MAE:  18613.87884179166
# MSE:  623584783.8897142
# RMSE:  24971.679636935
# R2:  0.5381098434327718

# %%
feature_importance = gb_reg.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + 0.5
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(1, 1, 1)
ax.bar(pos, feature_importance[sorted_idx], align='center')
plt.xticks(pos, np.array(x_df.columns)[sorted_idx])
ax.set_title('Feature Importance (MDI)')
fig.tight_layout()
plt.show()
