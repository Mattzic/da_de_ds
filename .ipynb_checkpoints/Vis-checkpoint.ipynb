# %%
import numpy as np
import pandas as pd
import re
import seaborn as sns
from numpy.random import default_rng
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_columns',100) 
pd.set_option('max_rows',500) 
File_Path = 'AllData.csv'
sns.set_style('darkgrid')

# %%
data = pd.read_csv(File_Path)

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)
data.head(100)
# Out:
#       Job Title             Salary Estimate  \
# 0   DataAnalyst  $37K-$66K (Glassdoor est.)
# 1   DataAnalyst  $37K-$66K (Glassdoor est.)
# 2   DataAnalyst  $37K-$66K (Glassdoor est.)
# 3   DataAnalyst  $37K-$66K (Glassdoor est.)
# 4   DataAnalyst  $37K-$66K (Glassdoor est.)
# 5   DataAnalyst  $37K-$66K (Glassdoor est.)
# 6   DataAnalyst  $37K-$66K (Glassdoor est.)
# 7   DataAnalyst  $37K-$66K (Glassdoor est.)
# 8   DataAnalyst  $37K-$66K (Glassdoor est.)
# 9   DataAnalyst  $37K-$66K (Glassdoor est.)
# 10  DataAnalyst  $37K-$66K (Glassdoor est.)
# 11  DataAnalyst  $37K-$66K (Glassdoor est.)
# 12  DataAnalyst  $37K-$66K (Glassdoor est.)
# 13  DataAnalyst  $37K-$66K (Glassdoor est.)
# 14  DataAnalyst  $37K-$66K (Glassdoor est.)
# 15  DataAnalyst  $37K-$66K (Glassdoor est.)
# 16  DataAnalyst  $37K-$66K (Glassdoor est.)
# 17  DataAnalyst  $37K-$66K (Glassdoor est.)
# 18  DataAnalyst  $37K-$66K (Glassdoor est.)
# 19  DataAnalyst  $37K-$66K (Glassdoor est.)
# 20  DataAnalyst  $37K-$66K (Glassdoor est.)
# 21  DataAnalyst  $37K-$66K (Glassdoor est.)
# 22  DataAnalyst  $37K-$66K (Glassdoor est.)
# 23  DataAnalyst  $37K-$66K (Glassdoor est.)
# 24  DataAnalyst  $37K-$66K (Glassdoor est.)
# 25  DataAnalyst  $37K-$66K (Glassdoor est.)
# 26  DataAnalyst  $37K-$66K (Glassdoor est.)
# 27  DataAnalyst  $37K-$66K (Glassdoor est.)
# 28  DataAnalyst  $37K-$66K (Glassdoor est.)
# 29  DataAnalyst  $37K-$66K (Glassdoor est.)
# 30  DataAnalyst  $46K-$87K (Glassdoor est.)
# 31  DataAnalyst  $46K-$87K (Glassdoor est.)
# 32  DataAnalyst  $46K-$87K (Glassdoor est.)
# 33  DataAnalyst  $46K-$87K (Glassdoor est.)
# 34  DataAnalyst  $46K-$87K (Glassdoor est.)
# 35  DataAnalyst  $46K-$87K (Glassdoor est.)
# 36  DataAnalyst  $46K-$87K (Glassdoor est.)
# 37  DataAnalyst  $46K-$87K (Glassdoor est.)
# 38  DataAnalyst  $46K-$87K (Glassdoor est.)
# 39  DataAnalyst  $46K-$87K (Glassdoor est.)
# 40  DataAnalyst  $46K-$87K (Glassdoor est.)
# 41  DataAnalyst  $46K-$87K (Glassdoor est.)
# 42  DataAnalyst  $46K-$87K (Glassdoor est.)
# 43  DataAnalyst  $46K-$87K (Glassdoor est.)
# 44  DataAnalyst  $46K-$87K (Glassdoor est.)
# 45  DataAnalyst  $46K-$87K (Glassdoor est.)
# 46  DataAnalyst  $46K-$87K (Glassdoor est.)
# 47  DataAnalyst  $46K-$87K (Glassdoor est.)
# 48  DataAnalyst  $46K-$87K (Glassdoor est.)
# 49  DataAnalyst  $46K-$87K (Glassdoor est.)
# 50  DataAnalyst  $46K-$87K (Glassdoor est.)
# 51  DataAnalyst  $46K-$87K (Glassdoor est.)
# 52  DataAnalyst  $46K-$87K (Glassdoor est.)
# 53  DataAnalyst  $46K-$87K (Glassdoor est.)
# 54  DataAnalyst  $46K-$87K (Glassdoor est.)
# 55  DataAnalyst  $46K-$87K (Glassdoor est.)
# 56  DataAnalyst  $46K-$87K (Glassdoor est.)
# 57  DataAnalyst  $46K-$87K (Glassdoor est.)
# 58  DataAnalyst  $46K-$87K (Glassdoor est.)
# 59  DataAnalyst  $46K-$87K (Glassdoor est.)
# 60  DataAnalyst  $51K-$88K (Glassdoor est.)
# 61  DataAnalyst  $51K-$88K (Glassdoor est.)
# 62  DataAnalyst  $51K-$88K (Glassdoor est.)
# 63  DataAnalyst  $51K-$88K (Glassdoor est.)
# 64  DataAnalyst  $51K-$88K (Glassdoor est.)
# 65  DataAnalyst  $51K-$88K (Glassdoor est.)
# 66  DataAnalyst  $51K-$88K (Glassdoor est.)
# 67  DataAnalyst  $51K-$88K (Glassdoor est.)
# 68  DataAnalyst  $51K-$88K (Glassdoor est.)
# 69  DataAnalyst  $51K-$88K (Glassdoor est.)
# 70  DataAnalyst  $51K-$88K (Glassdoor est.)
# 71  DataAnalyst  $51K-$88K (Glassdoor est.)
# 72  DataAnalyst  $51K-$88K (Glassdoor est.)
# 73  DataAnalyst  $51K-$88K (Glassdoor est.)
# 74  DataAnalyst  $51K-$88K (Glassdoor est.)
# 75  DataAnalyst  $51K-$88K (Glassdoor est.)
# 76  DataAnalyst  $51K-$88K (Glassdoor est.)
# 77  DataAnalyst  $51K-$88K (Glassdoor est.)
# 78  DataAnalyst  $51K-$88K (Glassdoor est.)
# 79  DataAnalyst  $51K-$88K (Glassdoor est.)
# 80  DataAnalyst  $51K-$88K (Glassdoor est.)
# 81  DataAnalyst  $51K-$88K (Glassdoor est.)
# 82  DataAnalyst  $51K-$88K (Glassdoor est.)
# 83  DataAnalyst  $51K-$88K (Glassdoor est.)
# 84  DataAnalyst  $51K-$88K (Glassdoor est.)
# 85  DataAnalyst  $51K-$88K (Glassdoor est.)
# 86  DataAnalyst  $51K-$88K (Glassdoor est.)
# 87  DataAnalyst  $51K-$88K (Glassdoor est.)
# 88  DataAnalyst  $51K-$88K (Glassdoor est.)
# 89  DataAnalyst  $51K-$88K (Glassdoor est.)
# 90  DataAnalyst  $51K-$87K (Glassdoor est.)
# 91  DataAnalyst  $51K-$87K (Glassdoor est.)
# 92  DataAnalyst  $51K-$87K (Glassdoor est.)
# 93  DataAnalyst  $51K-$87K (Glassdoor est.)
# 94  DataAnalyst  $51K-$87K (Glassdoor est.)
# 95  DataAnalyst  $51K-$87K (Glassdoor est.)
# 96  DataAnalyst  $51K-$87K (Glassdoor est.)
# 97  DataAnalyst  $51K-$87K (Glassdoor est.)
# 98  DataAnalyst  $51K-$87K (Glassdoor est.)
# 99  DataAnalyst  $51K-$87K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 0   Are you eager to roll up your sleeves and harn...     3.2
# 1   Overview\n\nProvides analytical and technical ...     3.8
# 2   We’re looking for a Senior Data Analyst who ha...     3.4
# 3   Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4   ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# 5   About Cubist\nCubist Systematic Strategies is ...     3.9
# 6   Two Sigma is a different kind of investment ma...     4.4
# 7   Data Science Analyst\n\nJob Details\nLevel\nEx...     3.7
# 8   The Data Analyst is an integral member of the ...     4.0
# 9   About Us\n\nRiskified is the AI platform power...     4.4
# 10  NYU Grossman School of Medicine is one of the ...     4.0
# 11  BulbHead is currently seeking a Data Analyst t...    -1.0
# 12  Job Summary:\n\nThe Clinical Research Data Ana...     3.7
# 13  About Known\n\nKnown is a modern marketing com...     3.0
# 14  Investment Advisory Compliance Opportunity in ...     3.4
# 15  Job Description\nRole Description\n\nSustainab...     3.6
# 16  Undertone stands alone among AdTech and ad net...     3.8
# 17  About Us:\n\nNYSTEC is a non-profit technology...     3.8
# 18  Company Description\n\nEDUCATION DEVELOPMENT C...     3.9
# 19  About Us\n\nAt Teachers Pay Teachers (TpT), we...     4.9
# 20  Note: By applying to this position your applic...     4.4
# 21  Job Description\nOur client, a music streaming...    -1.0
# 22  Data Analyst - Intex Developer\n\n\nNew York\n...     3.3
# 23  Haven Life is an insurtech innovator at MassMu...     3.5
# 24  Dash Technologies is an industry leading softw...     3.8
# 25  Data Analyst (Decision Science)\n\nHearst is a...     4.0
# 26  We are building Duolingo's newly formed FP&A /...     5.0
# 27  About Ro\nFounded in 2017, Ro is a patient-dri...     4.8
# 28  Type: Paid Intern (in a farm team)\n\nFunction...     3.7
# 29  The Company\n\nBlueLabs is a leading provider ...     4.7
# 30  Our Mission\n\nMove people.\n\nOur Values\n\nW...     3.6
# 31  Data Analyst Jersey City, NJ 12+ months contra...     3.6
# 32  Job Description:\nLegal experience is required...     3.5
# 33  Who we are\n\nSoFi is a digital personal finan...     3.2
# 34  Carry1st is the leading mobile game publisher ...    -1.0
# 35  Job Description:\n\nWithin GMC, Data & Portfol...     3.7
# 36  At Clear Street, we are disrupting the institu...    -1.0
# 37  If interested, please reach out to Iram Shah e...     3.6
# 38  NYU Grossman School of Medicine is one of the ...     4.0
# 39  Role: Data Analyst\n\nReports to: Manager of O...     4.6
# 40  Company Description\n\nPinto is building the w...    -1.0
# 41  About AB InBev\n\nAB InBev is the leading glob...    -1.0
# 42  Whip Media Group's products, including Mediamo...     5.0
# 43  Title: Data Analyst\n\nPosition: 1+ Year Contr...     4.0
# 44  Vettery is changing the way people hire and ge...     3.0
# 45  Non-Exempt*\nSchedule: Can be 8a.m. – 5p.m. or...     2.9
# 46  Advertising Data AnalystHearst Television is s...     4.0
# 47  MediaMath is a leading global independent adve...     3.6
# 48  Employment PermanentApply\nStart Date Immediat...     4.9
# 49  The Role:\n\nRoku is looking for a Senior Anal...     3.9
# 50  Job Summary:Comprised of Disney's internationa...     4.0
# 51  Job Description\n\nThe Team:\n\n\nWe are looki...     3.8
# 52  Summary Data Analysis, Financial Products basi...     3.7
# 53  Help us Build the Future of Money\n\nGemini Tr...     3.6
# 54  TSR is a premier National U.S. Staffing compan...     3.6
# 55  OverviewThe Data Analyst is a new position in ...    -1.0
# 56  Job Summary:Comprised of Disney's internationa...     4.0
# 57  Job Description\n\nOur NY office is seeking a ...     3.2
# 58  Job Requisition Number:82982\n\nAt Bloomberg, ...     3.8
# 59  Data Analyst (New York)\n\nAddThis Sharing But...     3.9
# 60  About Ro\nFounded in 2017, Ro is a patient-dri...     4.8
# 61  OverviewAt Perficient you'll deliver mission-c...     3.6
# 62  OverviewAt Perficient you'll deliver mission-c...     3.6
# 63  OverviewAt Perficient you'll deliver mission-c...     3.6
# 64  RESPONSIBILITIES:\n\nKforce has a client in se...     4.1
# 65  Who we are\nCriteo (NASDAQ: CRTO) is the globa...     3.9
# 66  Data Analyst Contract New York City Job 440 Pr...     3.0
# 67  Summary:\n\nThe International Equity Group man...     3.7
# 68  Job Details\n\nLevel\n\nExperienced\n\nJob Loc...    -1.0
# 69  Position Summary\nA data management/analyst wh...     3.9
# 70  Duration: 5 Months\n\nSchedule: Can be 8a.m. –...     3.7
# 71  Impakt Advisors is a brand new (2018), NYC bas...    -1.0
# 72  Marketing Data Analyst\n\nWe are a leading U.S...     3.6
# 73  The Data/Information Mgt Analyst is a strategi...     3.7
# 74  "This role is currently work-from-home and wil...     3.6
# 75  Org. Setting and Reporting\n\nThe United Natio...     4.1
# 76  Position SummaryOur Team: Media Strategy and A...     3.5
# 77  Data Analyst**job details:**+ location:Jersey ...     3.7
# 78  Job Description\nMulberry is disrupting a $40B...     5.0
# 79  Title: Data analyst with Python\n\nJob Type: 6...     4.0
# 80  Job Description\nRole: Data Analyst\nProject d...     4.8
# 81  Los Angeles, CA | New York, NY\n\nEmail career...     5.0
# 82  Guidepoint's Qsight team turns rows of data in...     3.3
# 83  BA/Data Analyst\nOur client, a global provider...     4.1
# 84  Use statistical analysis, machine learning, pa...     4.0
# 85  Our client is an innovative bitcoin marketplac...    -1.0
# 86  This is for Citi.\n\nBA/Data Analyst\n\n- Must...     1.0
# 87  Praescient Analytics, LLC (Praescient) is a Ve...     3.1
# 88  **We are still hiring and interviewing for thi...     4.5
# 89  The Ombudsman’s Office (OMB) is a neutral and ...     3.4
# 90  NYU Grossman School of Medicine is one of the ...    -1.0
# 91  Position Overview:\nThe\ndescriptive analytics...     3.6
# 92  RGP is a global consulting firm helping some o...     4.1
# 93  About Tachyon Technologies:\n\nTachyon Technol...     4.4
# 94  Job Description\n\n\nJob #: 1076857\n\nRole: F...     3.8
# 95  Hagerty Consulting (www.hagertyconsulting.com)...     3.2
# 96  Gainful is changing the way people shop for nu...    -1.0
# 97  Job Description\nCortex is a premier staffing ...     3.8
# 4    Arts, Entertainment & Recreation     100000000,500000000
# 5                             Finance                 Unknown
# 6                             Finance                 Unknown
# 7                           Insurance     100000000,500000000
# 8                             Finance   1000000000,2000000000
# 9                   Business Services                 Unknown
# 10                        Health Care  5000000000,10000000000
# 11                            Unknown                 Unknown
# 12                        Health Care   2000000000,5000000000
# 13                  Business Services     100000000,500000000
# 14                            Finance         1000000,5000000
# 15                  Business Services                 Unknown
# 16                  Business Services                 Unknown
# 17                  Business Services       25000000,50000000
# 18                  Business Services     100000000,500000000
# 19             Information Technology                 Unknown
# 20             Information Technology             10000000000
# 21                            Unknown                 Unknown
# 22                            Finance  5000000000,10000000000
# 23  Restaurants, Bars & Food Services         1000000,5000000
# 24                            Unknown                 Unknown
# 25                  Business Services        Less than1000000
# 26             Information Technology       10000000,25000000
# 27                        Health Care                 Unknown
# 28                  Business Services         1000000,5000000
# 29                  Business Services                 Unknown
# 30                  Business Services       25000000,50000000
# 31             Information Technology         1000000,5000000
# 32                            Unknown        Less than1000000
# 33                            Finance                 Unknown
# 34                            Unknown                 Unknown
# 35                            Finance             10000000000
# 36                            Unknown         1000000,5000000
# 37             Information Technology        Less than1000000
# 38                        Health Care  5000000000,10000000000
# 39                         Non-Profit       10000000,25000000
# 40                            Unknown                 Unknown
# 41                            Unknown                 Unknown
# 42                            Unknown                 Unknown
# 43                  Business Services         1000000,5000000
# 44             Information Technology                 Unknown
# 45                  Business Services    500000000,1000000000
# 46                  Business Services        Less than1000000
# 47                  Business Services     100000000,500000000
# 48                            Finance                 Unknown
# 49             Information Technology    500000000,1000000000
# 50                              Media             10000000000
# 51                            Unknown      50000000,100000000
# 52             Information Technology     100000000,500000000
# 53                            Finance                 Unknown
# 54                  Business Services      50000000,100000000
# 55                            Unknown                 Unknown
# 56                              Media             10000000000
# 57                 Accounting & Legal    500000000,1000000000
# 58             Information Technology                 Unknown
# 59                        Real Estate       25000000,50000000
# 60                        Health Care                 Unknown
# 61             Information Technology    500000000,1000000000
# 62             Information Technology    500000000,1000000000
# 63             Information Technology    500000000,1000000000
# 64                  Business Services   1000000000,2000000000
# 65             Information Technology   2000000000,5000000000
# 66             Information Technology         1000000,5000000
# 67                            Finance    500000000,1000000000
# 68                            Unknown                 Unknown
# 69             Information Technology     100000000,500000000
# 70                  Business Services      50000000,100000000
# 71                  Business Services                 Unknown
# 72                            Unknown                 Unknown
# 73                            Finance             10000000000
# 74                  Business Services     100000000,500000000
# 75                         Government                 Unknown
# 76                              Media  5000000000,10000000000
# 77                  Business Services                 Unknown
# 78                            Unknown                 Unknown
# 79                  Business Services         1000000,5000000
# 80                            Unknown                 Unknown
# 81             Information Technology                 Unknown
# 82                  Business Services                 Unknown
# 83                  Business Services     100000000,500000000
# 84                 Accounting & Legal        Less than1000000
# 85                            Unknown                 Unknown
# 86             Information Technology        Less than1000000
# 87                  Business Services       10000000,25000000
# 88                          Insurance                 Unknown
# 89                            Finance    500000000,1000000000
# 90                            Unknown                 Unknown
# 91                            Finance   2000000000,5000000000
# 64                                                 -1         -1    51000.0
# 65                    MediaMath, Conversant, AppNexus         -1    51000.0
# 66                                                 -1         -1    51000.0
# 67  Fidelity Investments, BlackRock, Putnam Invest...         -1    51000.0
# 68                                                 -1         -1    51000.0
# 69                                                 -1         -1    51000.0
# 70  Artech Information Systems, Mindlance, Tech Ma...         -1    51000.0
# 71                                                 -1         -1    51000.0
# 72                                                 -1         -1    51000.0
# 73                                                 -1         -1    51000.0
# 74                                                 -1         -1    51000.0
# 75                                                 -1         -1    51000.0
# 76                                                 -1         -1    51000.0
# 77                                                 -1         -1    51000.0
# 78                                                 -1         -1    51000.0
# 79                                                 -1         -1    51000.0
# 80                                                 -1         -1    51000.0
# 81                                                 -1         -1    51000.0
# 82        Coleman Research, AlphaSights, Third Bridge       True    51000.0
# 83                                                 -1         -1    51000.0
# 84                                                 -1         -1    51000.0
# 85                                                 -1         -1    51000.0
# 86                                                 -1         -1    51000.0
# 87                                                 -1         -1    51000.0
# 88                                                 -1       True    51000.0
# 89                                                 -1         -1    51000.0
# 90                                                 -1         -1    51000.0
# 91                                                 -1         -1    51000.0
# 92          Deloitte, Huron Consulting Group, Point B         -1    51000.0
# 93                                                 -1         -1    51000.0
# 94              TEKsystems, Insight Global, Accenture       True    51000.0
# 95                                                 -1         -1    51000.0
# 96                                                 -1         -1    51000.0
# 97                                                 -1         -1    51000.0
# 98                                                 -1         -1    51000.0
# 99                                                 -1         -1    51000.0
#
#     Hi Salary         Area State  Lo Em  Hi Em       Lo Rev       Hi Rev  \
# 0     66000.0     New York    NY    201    500    100000000    500000000
# 1     66000.0     New York    NY  10000     -1   2000000000   5000000000
# 2     66000.0     New York    NY   1001   5000           -1           -1
# 3     66000.0     New York    NY    201    500     50000000    100000000
# 4     66000.0     New York    NY    501   1000    100000000    500000000
# 5     66000.0     New York    NY   1001   5000           -1           -1
# 6     66000.0     New York    NY   1001   5000           -1           -1
# 7     66000.0     New York    NY    201    500    100000000    500000000
# 8     66000.0     New York    NY   5001  10000   1000000000   2000000000
# 9     66000.0     New York    NY    501   1000           -1           -1
# 10    66000.0     New York    NY  10000     -1   5000000000  10000000000
# 11    66000.0    Fairfield    NJ      1     50           -1           -1
# 12    66000.0     New York    NY  10000     -1   2000000000   5000000000
# 13    66000.0     New York    NY    201    500    100000000    500000000
# 14    66000.0  Jersey City    NJ   1001   5000      1000000      5000000
# 15    66000.0     New York    NY      1     50           -1           -1
# 16    66000.0     New York    NY    201    500           -1           -1
# 17    66000.0     New York    NY     51    200     25000000     50000000
# 18    66000.0     New York    NY    501   1000    100000000    500000000
# 19    66000.0     New York    NY     51    200           -1           -1
# 20    66000.0     New York    NY  10000     -1  10000000000  10000000000
# 21    66000.0     New York    NY     -1     -1           -1           -1
# 22    66000.0     New York    NY  10000     -1   5000000000  10000000000
# 23    66000.0     New York    NY    201    500      1000000      5000000
# 24    66000.0     New York    NY      1     50           -1           -1
# 25    66000.0     New York    NY      1     50           -1      1000000
# 26    66000.0     New York    NY    201    500     10000000     25000000
# 98   Large   Large
# 99  Medium   Small

# %%
len(data)
# Out:
# 8690

# %% [markdown]
# # 三种职业薪水的基本情况及比较

# %% [markdown]
# ## 1. 从收入中位数看，DA收入明显低于DE，DS；<br>2. DE，DS收入虽有差距，但差距不大。

# %%
df = data[['Lo Salary', 'Hi Salary']].groupby(data['Job Title']).median()

fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(1,1,1)
bar_width = 0.3
index = df.index
x = range(len(index))
y1 = df['Lo Salary']
y2 = df['Hi Salary']
bar1 = ax1.bar(x=[i-0.2 for i in x], 
               height=y1, 
               width=bar_width, 
               alpha=0.7, 
               color='dodgerblue', 
               label='Median_LSalary')
bar2 = ax1.bar(x=[i+0.2 for i in x],
              height=y2,
              width=bar_width,
              alpha=0.7,
              color='mediumseagreen',
              label='Median_MSalary')
ax1.set_title('Median Salary For DA DE and DS', fontsize=20)
plt.xticks(x, index, fontsize=12)
plt.xlabel('Job Title',fontsize=14)
plt.yticks(fontsize=12)
plt.ylabel('Salary',fontsize=14)
plt.ylim(df['Lo Salary'].min()-10000, df['Hi Salary'].max()+10000)
plt.legend()

for bar in bar1:
    value = bar.get_height()
    plt.text(bar.get_x()+bar.get_width()/2, value+8, str(int(value)), ha='center', size='medium')
for bar in bar2:
    value = bar.get_height()
    plt.text(bar.get_x()+bar.get_width()/2, value+8, str(int(value)), ha='center', size='medium')
plt.show()

# %% [markdown]
# # 公司规模和工作机会及工资收入的关系

# %% [markdown]
# ## 1. 大公司（收入，雇员人数）提供了大部分的数据相关的工作；<br> 2. 意外地，不同规模的企业提供的数据相关工作的工资水平大体相当 。

# %%
df1 = data['BS_R'].value_counts()
df2 = data[['Lo Salary', 'Hi Salary']].groupby(data['BS_R']).median()
df2 = df2.reindex(index=['Large', 'Medium', 'Small', 'Micro', 'Other'])

# %%
fig = plt.figure(figsize=(12,24))
ax1 = fig.add_subplot(2,1,1)

v = df1.values
ax1.set_title('Jobs Provided by Companies of Different Company Size ', fontsize=14)
patches, l_text, p_text = plt.pie(v, 
                                  labels=df1.index, 
                                  autopct='%.1f %%',
                                  startangle=90,
                                  shadow=True)
for i in p_text:
    i.set_size(10)
    i.set_color('k')

plt.legend()
plt.plot()

ax2 = fig.add_subplot(2,1,2)
bar_width = 0.3
index = df2.index
x = range(len(index))
y1 = df2['Lo Salary']
y2 = df2['Hi Salary']
bar1 = ax2.bar(x=[i-0.2 for i in x], 
               height=y1, 
               width=bar_width, 
               alpha=0.7, 
               color='tomato', 
               label='Median_LSalary')
bar2 = ax2.bar(x=[i+0.2 for i in x],
              height=y2,
              width=bar_width,
              alpha=0.7,
              color='cornflowerblue',
              label='Median_MSalary')
ax2.set_title('Median Salary in Companies of Different Company Size', fontsize=20)
plt.xticks(x, index, fontsize=12)
plt.xlabel('Company Size',fontsize=14)
plt.yticks(fontsize=12)
plt.ylabel('Salary',fontsize=14)
plt.ylim(df2['Lo Salary'].min()-10000, df2['Hi Salary'].max()+10000)
plt.legend()

for bar in bar1:
    value = bar.get_height()
    plt.text(bar.get_x()+bar.get_width()/2, value+8, str(int(value)), ha='center', size='medium')
for bar in bar2:
    value = bar.get_height()
    plt.text(bar.get_x()+bar.get_width()/2, value+8, str(int(value)), ha='center', size='medium')
    
plt.show()

# %% [markdown]
# # Job Description中一些关于语言,常用软件,学历的简单统计

# %% [markdown]
# ## 1. 常用的最5种语言 R, Sql, Python, Java, C++ <br> 2. 最常用的5个软件Excel, Spark, Tableau , Hadoop, Sas <br> 3. DS 对PhD需求量大, 远超 DA, DE; DA, DE对学历的要求基本一致

# %%
language = {'Python':0, 'R':0, 'SQL':0, 'Java':0, 'C++':0 , 'c#':0}
for key in language.keys():
    if key == 'C++':
        key = 'C\+\+'
    value = len(data[data['Job Description'].str.contains(key, regex=True, flags=re.IGNORECASE)])
    if key == 'C\+\+':
        key = 'C++'
    language[key] = value

df1 = pd.DataFrame(language, index=['counts']).T
df1.sort_values('counts', inplace=True, ascending=False)
df1_ = df1.iloc[0:5]

# %%
software = {'Excel':0, 'Word':0, 'Powerpoint':0, 'Tableau':0, 'PowerBI':0, 'Hadoop':0, 'Spark':0, 'Jira':0, 'Sas':0, 'Spss':0,'Stata':0}
for key in software.keys():
    if key == 'PowerBI':
        key = 'Power\s*BI'
    value = len(data[data['Job Description'].str.contains(key, regex=True, flags=re.IGNORECASE)])
    if key == 'Power\s*BI':
        key = 'PowerBI'
    software[key] = value

df2 = pd.DataFrame(software, index=['counts']).T
df2.sort_values('counts', inplace=True, ascending=False)
df2_ = df2.iloc[0:5]

# %%
degree = ['Bachelor', 'Master', 'PhD']
jobs = ['DataAnalyst','DataEngineer','DataScientist']
df_list= []
i = 0
for job in jobs:
    for d in degree:
        value = len(data[(data['Job Title'] == job) & (data['Job Description'].str.contains(d, regex=True, flags=re.IGNORECASE))])
        df3 = pd.DataFrame({'Counts': value, 'Degree': d, 'Job': job}, index=[i]) 
        df_list.append(df3)
        i += 1

df3 = pd.concat(df_list)

# %%
def bar_plot(ax, df, colors, xlabel, ylabel, bwidth, lsize, tsize):
    y = list(df.counts)
    index = df.index
    x = range(len(index))
    bar_width = bwidth

    bar = ax.bar(x, 
                  y, 
                  width=bar_width, 
                  color=colors,
                  alpha=0.7)

    ax.set_xlabel(xlabel, fontsize=lsize)
    ax.set_xticks(x)
    ax.set_xticklabels(index, fontsize=tsize)
    ax.set_ylabel(ylabel, fontsize=lsize)

    for b in bar:
        v = b.get_height()
        x = b.get_x() + bar_width / 2
        ax.text(x, v+8, str(v), ha='center', size='medium')

# %%
fig = plt.figure(figsize=(24,12))
ax1 = fig.add_subplot(2,2,1)
colors=['darksalmon','darkorange','darkseagreen','blueviolet','navy']   
bar_plot(ax1, df1_, colors, 'Language', 'Counts', 0.4, 14, 12)

ax2 = fig.add_subplot(2,2,2)
bar_plot(ax2, df2_, colors, 'Software', 'Counts', 0.4, 14, 12)

ax3 = fig.add_subplot(2,2,3)
sns.barplot(x='Job', y="Counts", hue="Degree", data=df3)

# from stack overflow
def show_on_single_plot(ax):        
    for p in ax.patches:
        _x = p.get_x() + p.get_width() / 2
        _y = p.get_y() + p.get_height()
        value = int(p.get_height())
        ax.text(_x, _y, value, ha="center")
show_on_single_plot(ax3)

ax4 = fig.add_subplot(2,2,4)
f_name = 'JD.txt'
with open(f_name, 'w+') as f:
    for index, row in data.iterrows():
        f.write(str(row['Job Description']))
    f.seek(0, 0)    
    text = f.read()
    wordcloud = WordCloud(width=1200,height=600).generate(text)
    ax4.imshow(wordcloud, interpolation='bilinear')
    ax4.axis("off")

plt.show()

# %%
# to do: 地域和工作机会及薪资的关系, 考虑画 gis 图

# %%
df1 = data['State'].value_counts()
other = df1[9:].values.sum()
df1 = df1[:9]
df1['other'] = 395

# df2 = data['Lo Salary'].groupby(data['State']).min()
# df2 = pd.DataFrame({'State':df2.index, 'Value': df2.values, 'Cata': 'Lo Salary'})
# df2.drop(index=17, inplace=True)
# df2.set_index(['State'], inplace=True)
# df3 = data['Hi Salary'].groupby(data['State']).max()
# df3 = pd.DataFrame({'State':df3.index, 'Value': df3.values, 'Cata': 'Hi Salary'})
# df3.drop(index=17, inplace=True)
# df3.set_index(['State'], inplace=True)
# df = pd.concat([df2,df3])
# df
# Out:
#           Value       Cata
# State
#  AZ     43000.0  Lo Salary
#  CA     34000.0  Lo Salary
#  CO     49000.0  Lo Salary
#  DE     37000.0  Lo Salary
#  FL     27000.0  Lo Salary
#  GA     32000.0  Lo Salary
#  IL     31000.0  Lo Salary
#  IN     34000.0  Lo Salary
#  KS     36000.0  Lo Salary
#  NC     40000.0  Lo Salary
#  NJ     27000.0  Lo Salary
#  NY     27000.0  Lo Salary
#  OH     28000.0  Lo Salary
#  PA     37000.0  Lo Salary
#  SC     53000.0  Lo Salary
#  TX     12000.0  Lo Salary
#  UT     26000.0  Lo Salary
#  VA     43000.0  Lo Salary
#  WA     35000.0  Lo Salary
#  AZ    187000.0  Hi Salary
#  CA    250000.0  Hi Salary
#  CO    104000.0  Hi Salary
#  DE    281000.0  Hi Salary
#  FL    141000.0  Hi Salary
#  GA     56000.0  Hi Salary
#  IL    210000.0  Hi Salary
#  IN     61000.0  Hi Salary
#  KS     67000.0  Hi Salary
#  NC     99000.0  Hi Salary
#  NJ    237000.0  Hi Salary
#  NY    254000.0  Hi Salary
#  OH    163000.0  Hi Salary
#  PA    281000.0  Hi Salary
#  SC     99000.0  Hi Salary
#  TX    217000.0  Hi Salary
#  UT     59000.0  Hi Salary
#  VA    112000.0  Hi Salary
#  WA    101000.0  Hi Salary

# %%
fig = plt.figure(figsize=(12,24))
ax1 = fig.add_subplot(2,1,1)

v = df1.values
ax1.set_title('Jobs in Different States', fontsize=14)
patches, l_text, p_text = ax1.pie(v, 
                                  labels=df1.index, 
                                  autopct='%.1f %%',
                                  startangle=90,
                                  wedgeprops=dict(width=0.6,edgecolor='w'))
for i in p_text:
    i.set_size(10)
    i.set_color('k')

for i in l_text:
    i.set_size(12)
    i.set_color('k')

ax1.legend()

ax1 = fig.add_subplot(2,1,1)

plt.show()
